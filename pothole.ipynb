# %% [markdown]
# <a href="https://colab.research.google.com/github/s-joona/Data_Analytics/blob/main/pothole.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests #클래스도 아님 파이썬 내에 존재
import json

url = 'http://apis.data.go.kr/6450000/potholecvlcpts/getpotholecvlcpts'
service_key = '5YMH8rKaeWwe2y4mst6BKGTlwPdQ2g0BAgf2ZTa8oiYaOO02zoC9pyJfIxAOfOdAMEUfbxu2yXHOyScaxxWUnA=='
params = {
    'serviceKey' : service_key , 
     'numOfRows' : '1252',
    'type' : 'json' 
}

reqs = requests.get(url, params = params)
load_json = json.loads(reqs.text)

df = pd.DataFrame(load_json['items'])
df.columns=['날짜','위치','요청사항','위도','경도']
df
# Out:
#              날짜                                       위치  \
# 0    2018-01-06  전라북도 군산시 임피면 영창리 831-2번지 일원 (지방도 718호선)
# 1    2018-01-09            전라북도 고창군 해리면 고성리 일원 (국지도15호선)
# 2    2018-02-18  전라북도 순창군 유등면 창신리 272-9번지 일원 (지방도 730호선)
# 3    2018-04-05       전라북도 무주군 적상면 북창리 산 22-1(지방도 727호선)
# 4    2018-04-07                   전라북도 익산시 황등면 동연리 646-5
# ..          ...                                      ...
# 247  2021-06-20                 전라북도 남원시 주천면 고기리 산 107-8
# 248  2021-06-23                                김제 IC 사거리
# 249  2021-06-25       전라북도 남원시 주천면 송치리 산 82-1 (국지도 60호선)
# 250  2021-07-04                                김제 IC 사거리
# 251  2021-07-04                     전라북도 김제시 금구면 옥성리 714
#
#                                         요청사항          위도           경도
# 0    지방도 718호선 대령마을 부근 가상과속방지턱 설치 관련 진행상황 요청   35.971774  126.8770854
# 1                회전교차로(송산교차로)설치 요청 건 진행사항 문의  35.4463684  126.5532242
# ...

# %%
import time 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests #클래스도 아님 파이썬 내에 존재
import json

url = 'http://apis.data.go.kr/6450000/potholes/getpotholes'
service_key = '5YMH8rKaeWwe2y4mst6BKGTlwPdQ2g0BAgf2ZTa8oiYaOO02zoC9pyJfIxAOfOdAMEUfbxu2yXHOyScaxxWUnA=='
params = {
    'serviceKey' : service_key , 
     'numOfRows' : '1252',
    'type' : 'json' 
}

reqs = requests.get(url, params = params)
load_json = json.loads(reqs.text)

df = pd.DataFrame(load_json['items'])
df.columns=['년도','일자','노선명','작업구간','위치','보수내용','위도','경도']
df
# Out:
#        년도     일자  노선명       작업구간                       위치 보수내용           위도  \
# 0    2021  01-21  713   이서 - 대문안   전라북도 김제시 만경읍 송상리 428-5  포트홀   35.8722533
# 1    2021  01-21  716  이서 - 김제시계  전라북도 완주군 이서면 은교리 산224-1  포트홀   35.8201214
# 2    2021  01-21  702    와룡 - 진봉    전라북도 김제시 진봉면 고사리 18-3  포트홀   35.8565378
# 3    2021  01-21  734       남원대산     전라북도 남원시 대산면 옥율리 744  포트홀   35.4516778
# 4    2021  01-21  734       남원대산     전라북도 남원시 대산면 옥율리 744  포트홀  35.45110431
# ..    ...    ...  ...        ...                      ...  ...          ...
# 226  2021  07-05  716  이서 - 김제시계   전라북도 완주군 이서면 이성리 165-4  포트홀  35.82107255
# 227  2021  07-05  799    삼례 - 봉동   전라북도 완주군 봉동읍 장구리 579-4  포트홀   35.9681295
# 228  2021  07-05  714    금구 - 황산     전라북도 김제시 금구면 옥성리 688  포트홀   35.7822345
# 229  2021  07-05  714    금구 - 황산     전라북도 김제시 금구면 옥성리 725  포트홀   35.7818509
# 230  2021  07-05  714    금구 - 황산     전라북도 김제시 금구면 옥성리 725  포트홀  35.78176894
#
#               경도
# 0    126.8248111
# 1    127.0060674
# ...
